# %% [markdown]
# # ■ 사용한 데이터 셋 종류가 어떤 차이가 있는지 비교하기 위해 정리

# %% [markdown]
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ---

# %% [markdown]
# # ■ 기타 자료

# %% [markdown]
# ### ▶ 주차별 계획서

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### ▶ 중간점검보고서

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### ▶ 그 외 자료

# %% [markdown]
# ![image.png](attachment:image.png)
