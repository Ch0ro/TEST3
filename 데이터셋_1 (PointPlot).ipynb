# %%
import pandas as pd
import numpy as np
import re
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

# %%
data = pd.read_csv('./csv파일/데이터셋_1.csv',encoding='cp949')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58059 entries, 0 to 58058
# Data columns (total 33 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   요일           58059 non-null  object
#  1   사고내용         58059 non-null  object
#  2   사고유형         58059 non-null  object
#  3   가해자성별        58059 non-null  object
#  4   피해자성별        58059 non-null  object
#  5   연령가해자        58059 non-null  int64
#  6   연령피해자        58059 non-null  int64
#  7   가해자음주        58059 non-null  object
#  8   법규위반가해자      58059 non-null  object
#  9   행동유형가해자      58059 non-null  object
#  10  신체상해정도가해자    58059 non-null  object
#  11  신체상해정도피해자    58059 non-null  object
#  12  가해자신체상해주부위   58059 non-null  object
#  13  피해자신체상해주부위   58059 non-null  object
#  14  차량용도가해자_중분류  58059 non-null  object
#  15  도로종류         58059 non-null  object
#  16  도로형태         58059 non-null  object
#  17  노인보호구역_여부    58059 non-null  object
# ...

# %% [markdown]
# # ■ 아래 결과에 따른 순서척도 변환 결과

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 1. 종속변수 EPDO1 사용

# %%
old_pedestrian = data

# %%
len(old_pedestrian)
# Out:
# 58059

# %%
fig, axes = plt.subplots(2,2)

sns.pointplot(x='요일',y='EPDO1', data=old_pedestrian, ax=axes[0][0],color='blue')
sns.pointplot(x='사고내용',y='EPDO1', data=old_pedestrian, ax=axes[0][1],color='blue')
sns.pointplot(x='사고유형',y='EPDO1', data=old_pedestrian, ax=axes[1][0],color='blue')
sns.pointplot(x='가해자성별',y='EPDO1', data=old_pedestrian, ax=axes[1][1],color='blue')

fig.set_size_inches(15,10)
plt.show()

# %%
fig, axes = plt.subplots(2,2)

sns.pointplot(x='피해자성별',y='EPDO1', data=old_pedestrian, ax=axes[0][0],color='blue')
sns.pointplot(x='연령가해자',y='EPDO1', data=old_pedestrian, ax=axes[0][1],color='blue')
sns.pointplot(x='연령피해자',y='EPDO1', data=old_pedestrian, ax=axes[1][0],color='blue')
sns.pointplot(x='가해자음주',y='EPDO1', data=old_pedestrian, ax=axes[1][1],color='blue')

fig.set_size_inches(15,10)
plt.show()

# %%
fig, (ax1,ax2) = plt.subplots(2,1,figsize=(25,20))

sns.pointplot(x='연령가해자',y='EPDO1', data=old_pedestrian, ax=ax1,color='blue')
sns.pointplot(x='연령피해자',y='EPDO1', data=old_pedestrian, ax=ax2,color='blue')

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(2,2)

sns.pointplot(x='법규위반가해자',y='EPDO1', data=old_pedestrian, ax=axes[0][0],color='blue')
sns.pointplot(x='행동유형가해자',y='EPDO1', data=old_pedestrian, ax=axes[0][1],color='blue')
sns.pointplot(x='신체상해정도가해자',y='EPDO1', data=old_pedestrian, ax=axes[1][0],color='blue')
sns.pointplot(x='신체상해정도피해자',y='EPDO1', data=old_pedestrian, ax=axes[1][1],color='blue')

fig.set_size_inches(15,10)
plt.show()

# %%
fig, axes = plt.subplots(2,2)

sns.pointplot(x='가해자신체상해주부위',y='EPDO1', data=old_pedestrian, ax=axes[0][0])
sns.pointplot(x='피해자신체상해주부위',y='EPDO1', data=old_pedestrian, ax=axes[0][1])
sns.pointplot(x='차량용도가해자_중분류',y='EPDO1', data=old_pedestrian, ax=axes[1][0])
sns.pointplot(x='도로종류',y='EPDO1', data=old_pedestrian, ax=axes[1][1])

fig.set_size_inches(15,10)
plt.show()

# %%
fig, (ax1) = plt.subplots(1,1,figsize=(25,20))

sns.pointplot(x='차량용도가해자_중분류',y='EPDO1', data=old_pedestrian, ax=ax1)


plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(2,2)

sns.pointplot(x='도로형태',y='EPDO1', data=old_pedestrian, ax=axes[0][0])
sns.pointplot(x='노인보호구역_여부',y='EPDO1', data=old_pedestrian, ax=axes[0][1])
sns.pointplot(x='어린이보호구역_여부',y='EPDO1', data=old_pedestrian, ax=axes[1][0])
sns.pointplot(x='자전거도로_여부',y='EPDO1', data=old_pedestrian, ax=axes[1][1])

fig.set_size_inches(15,10)
plt.show()

# %%
fig, axes = plt.subplots(2,2)

sns.pointplot(x='도로선형',y='EPDO1', data=old_pedestrian, ax=axes[0][0])
sns.pointplot(x='기상상태',y='EPDO1', data=old_pedestrian, ax=axes[0][1])
sns.pointplot(x='노면상태',y='EPDO1', data=old_pedestrian, ax=axes[1][0])
sns.pointplot(x='교차로형태',y='EPDO1', data=old_pedestrian, ax=axes[1][1])

fig.set_size_inches(15,10)
plt.show()

# %%
fig, axes = plt.subplots(2,2)

sns.pointplot(x='사망자수',y='EPDO1', data=old_pedestrian, ax=axes[0][0])
sns.pointplot(x='중상자수',y='EPDO1', data=old_pedestrian, ax=axes[0][1])
sns.pointplot(x='경상자수',y='EPDO1', data=old_pedestrian, ax=axes[1][0])
sns.pointplot(x='부상신고자수',y='EPDO1', data=old_pedestrian, ax=axes[1][1])

fig.set_size_inches(15,10)
plt.show()

# %%
fig, (ax1,ax2) = plt.subplots(2,1,figsize=(25,20))

sns.pointplot(x='발생시각',y='EPDO1', data=old_pedestrian, ax=ax1)
sns.pointplot(x='가해자차량용도',y='EPDO1', data=old_pedestrian, ax=ax2)

plt.tight_layout()
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # 2. 종속변수 EPDO2 사용

# %%
fig, axes = plt.subplots(2,2)

sns.pointplot(x='요일',y='EPDO2', data=old_pedestrian, ax=axes[0][0],color="#bb3f3f")
sns.pointplot(x='사고내용',y='EPDO2', data=old_pedestrian, ax=axes[0][1],color="#bb3f3f")
sns.pointplot(x='사고유형',y='EPDO2', data=old_pedestrian, ax=axes[1][0],color="#bb3f3f")
sns.pointplot(x='가해자성별',y='EPDO2', data=old_pedestrian, ax=axes[1][1],color="#bb3f3f")

fig.set_size_inches(15,10)
plt.show()

# %%
fig, axes = plt.subplots(2,2)

sns.pointplot(x='피해자성별',y='EPDO2', data=old_pedestrian, ax=axes[0][0],color="#bb3f3f")
sns.pointplot(x='연령가해자',y='EPDO2', data=old_pedestrian, ax=axes[0][1],color="#bb3f3f")
sns.pointplot(x='연령피해자',y='EPDO2', data=old_pedestrian, ax=axes[1][0],color="#bb3f3f")
sns.pointplot(x='가해자음주',y='EPDO2', data=old_pedestrian, ax=axes[1][1],color="#bb3f3f")

fig.set_size_inches(15,10)
plt.show()

# %%
fig, (ax1,ax2) = plt.subplots(2,1,figsize=(25,20))

sns.pointplot(x='연령가해자',y='EPDO2', data=old_pedestrian, ax=ax1,color="#bb3f3f")
sns.pointplot(x='연령피해자',y='EPDO2', data=old_pedestrian, ax=ax2,color="#bb3f3f")

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(2,2)

sns.pointplot(x='법규위반가해자',y='EPDO2', data=old_pedestrian, ax=axes[0][0],color="#bb3f3f")
sns.pointplot(x='행동유형가해자',y='EPDO2', data=old_pedestrian, ax=axes[0][1],color="#bb3f3f")
sns.pointplot(x='신체상해정도가해자',y='EPDO2', data=old_pedestrian, ax=axes[1][0],color="#bb3f3f")
sns.pointplot(x='신체상해정도피해자',y='EPDO2', data=old_pedestrian, ax=axes[1][1],color="#bb3f3f")

fig.set_size_inches(15,10)
plt.show()

# %%
fig, axes = plt.subplots(2,2)

sns.pointplot(x='가해자신체상해주부위',y='EPDO2', data=old_pedestrian, ax=axes[0][0],color="#bb3f3f")
sns.pointplot(x='피해자신체상해주부위',y='EPDO2', data=old_pedestrian, ax=axes[0][1],color="#bb3f3f")
sns.pointplot(x='차량용도가해자_중분류',y='EPDO2', data=old_pedestrian, ax=axes[1][0],color="#bb3f3f")
sns.pointplot(x='도로종류',y='EPDO2', data=old_pedestrian, ax=axes[1][1],color="#bb3f3f")

fig.set_size_inches(15,10)
plt.show()

# %%
fig, (ax1) = plt.subplots(1,1,figsize=(25,20))

sns.pointplot(x='차량용도가해자_중분류',y='EPDO2', data=old_pedestrian, ax=ax1,color="#bb3f3f")


plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(2,2)

sns.pointplot(x='도로형태',y='EPDO2', data=old_pedestrian, ax=axes[0][0],color="#bb3f3f")
sns.pointplot(x='노인보호구역_여부',y='EPDO2', data=old_pedestrian, ax=axes[0][1],color="#bb3f3f")
sns.pointplot(x='어린이보호구역_여부',y='EPDO2', data=old_pedestrian, ax=axes[1][0],color="#bb3f3f")
sns.pointplot(x='자전거도로_여부',y='EPDO2', data=old_pedestrian, ax=axes[1][1],color="#bb3f3f")

fig.set_size_inches(15,10)
plt.show()

# %%
fig, axes = plt.subplots(2,2)

sns.pointplot(x='도로선형',y='EPDO2', data=old_pedestrian, ax=axes[0][0],color="#bb3f3f")
sns.pointplot(x='기상상태',y='EPDO2', data=old_pedestrian, ax=axes[0][1],color="#bb3f3f")
sns.pointplot(x='노면상태',y='EPDO2', data=old_pedestrian, ax=axes[1][0],color="#bb3f3f")
sns.pointplot(x='교차로형태',y='EPDO2', data=old_pedestrian, ax=axes[1][1],color="#bb3f3f")

fig.set_size_inches(15,10)
plt.show()

# %%
fig, axes = plt.subplots(2,2)

sns.pointplot(x='사망자수',y='EPDO2', data=old_pedestrian, ax=axes[0][0],color="#bb3f3f")
sns.pointplot(x='중상자수',y='EPDO2', data=old_pedestrian, ax=axes[0][1],color="#bb3f3f")
sns.pointplot(x='경상자수',y='EPDO2', data=old_pedestrian, ax=axes[1][0],color="#bb3f3f")
sns.pointplot(x='부상신고자수',y='EPDO2', data=old_pedestrian, ax=axes[1][1],color="#bb3f3f")

fig.set_size_inches(15,10)
plt.show()

# %%
fig, (ax1,ax2) = plt.subplots(2,1,figsize=(25,20))

sns.pointplot(x='발생시각',y='EPDO2', data=old_pedestrian, ax=ax1,color="#bb3f3f")
sns.pointplot(x='가해자차량용도',y='EPDO2', data=old_pedestrian, ax=ax2,color="#bb3f3f")

plt.tight_layout()
plt.show()

# %% [markdown]
# # 3. 종속변수 심각도 사용

# %%
fig, axes = plt.subplots(2,2)

sns.pointplot(x='요일',y='심각도', data=old_pedestrian, ax=axes[0][0],color='green')
sns.pointplot(x='사고내용',y='심각도', data=old_pedestrian, ax=axes[0][1],color='green')
sns.pointplot(x='사고유형',y='심각도', data=old_pedestrian, ax=axes[1][0],color='green')
sns.pointplot(x='가해자성별',y='심각도', data=old_pedestrian, ax=axes[1][1],color='green')

fig.set_size_inches(15,10)
plt.show()

# %%
fig, axes = plt.subplots(2,2)

sns.pointplot(x='피해자성별',y='EPDO1', data=old_pedestrian, ax=axes[0][0],color='green')
sns.pointplot(x='연령가해자',y='EPDO1', data=old_pedestrian, ax=axes[0][1],color='green')
sns.pointplot(x='연령피해자',y='EPDO1', data=old_pedestrian, ax=axes[1][0],color='green')
sns.pointplot(x='가해자음주',y='EPDO1', data=old_pedestrian, ax=axes[1][1],color='green')

fig.set_size_inches(15,10)
plt.show()

# %%
fig, (ax1,ax2) = plt.subplots(2,1,figsize=(25,20))

sns.pointplot(x='연령가해자',y='심각도', data=old_pedestrian, ax=ax1,color='green')
sns.pointplot(x='연령피해자',y='심각도', data=old_pedestrian, ax=ax2,color='green')

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(2,2)

sns.pointplot(x='법규위반가해자',y='심각도', data=old_pedestrian, ax=axes[0][0],color='green')
sns.pointplot(x='행동유형가해자',y='심각도', data=old_pedestrian, ax=axes[0][1],color='green')
sns.pointplot(x='신체상해정도가해자',y='심각도', data=old_pedestrian, ax=axes[1][0],color='green')
sns.pointplot(x='신체상해정도피해자',y='심각도', data=old_pedestrian, ax=axes[1][1],color='green')

fig.set_size_inches(15,10)
plt.show()

# %%
fig, axes = plt.subplots(2,2)

sns.pointplot(x='가해자신체상해주부위',y='심각도', data=old_pedestrian, ax=axes[0][0],color='green')
sns.pointplot(x='피해자신체상해주부위',y='심각도', data=old_pedestrian, ax=axes[0][1],color='green')
sns.pointplot(x='차량용도가해자_중분류',y='심각도', data=old_pedestrian, ax=axes[1][0],color='green')
sns.pointplot(x='도로종류',y='심각도', data=old_pedestrian, ax=axes[1][1],color='green')

fig.set_size_inches(15,10)
plt.show()

# %%
fig, (ax1) = plt.subplots(1,1,figsize=(25,20))

sns.pointplot(x='차량용도가해자_중분류',y='심각도', data=old_pedestrian, ax=ax1,color='green')


plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(2,2)

sns.pointplot(x='도로형태',y='심각도', data=old_pedestrian, ax=axes[0][0],color='green')
sns.pointplot(x='노인보호구역_여부',y='심각도', data=old_pedestrian, ax=axes[0][1],color='green')
sns.pointplot(x='어린이보호구역_여부',y='심각도', data=old_pedestrian, ax=axes[1][0],color='green')
sns.pointplot(x='자전거도로_여부',y='심각도', data=old_pedestrian, ax=axes[1][1],color='green')

fig.set_size_inches(15,10)
plt.show()

# %%
fig, axes = plt.subplots(2,2)

sns.pointplot(x='도로선형',y='심각도', data=old_pedestrian, ax=axes[0][0],color='green')
sns.pointplot(x='기상상태',y='심각도', data=old_pedestrian, ax=axes[0][1],color='green')
sns.pointplot(x='노면상태',y='심각도', data=old_pedestrian, ax=axes[1][0],color='green')
sns.pointplot(x='교차로형태',y='심각도', data=old_pedestrian, ax=axes[1][1],color='green')

fig.set_size_inches(15,10)
plt.show()

# %%
fig, axes = plt.subplots(2,2)

sns.pointplot(x='사망자수',y='심각도', data=old_pedestrian, ax=axes[0][0],color='green')
sns.pointplot(x='중상자수',y='심각도', data=old_pedestrian, ax=axes[0][1],color='green')
sns.pointplot(x='경상자수',y='심각도', data=old_pedestrian, ax=axes[1][0],color='green')
sns.pointplot(x='부상신고자수',y='심각도', data=old_pedestrian, ax=axes[1][1],color='green')

fig.set_size_inches(15,10)
plt.show()

# %%
fig, (ax1,ax2) = plt.subplots(2,1,figsize=(25,20))

sns.pointplot(x='발생시각',y='심각도', data=old_pedestrian, ax=ax1,color='green')
sns.pointplot(x='가해자차량용도',y='심각도', data=old_pedestrian, ax=ax2,color='green')

plt.tight_layout()
plt.show()

# %% [markdown]
# ---
