# %%
import pandas as pd
from sklearn import datasets
from sklearn.model_selection import train_test_split
from statsmodels.api import OLS

# %%
df=pd.read_csv('C:/Users/user/TEST3/csv파일/데이터셋_3(심각도).csv',encoding='cp949')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58059 entries, 0 to 58058
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   사고유형        58059 non-null  object
#  1   연령가해자       58059 non-null  object
#  2   법규위반가해자     58059 non-null  object
#  3   행동유형가해자     58059 non-null  object
#  4   피해자신체상해주부위  58059 non-null  object
#  5   차량용도가해자     58059 non-null  object
#  6   도로종류        58059 non-null  object
#  7   도로형태        58059 non-null  object
#  8   도로선형        58059 non-null  object
#  9   발생시각        58059 non-null  object
#  10  심각도         58059 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 4.9+ MB

# %%
df
# Out:
#              사고유형   연령가해자 법규위반가해자 행동유형가해자 피해자신체상해주부위 차량용도가해자 도로종류 도로형태 도로선형  \
# 0           보도통행중   20세이하     그룹1     그룹2        그룹4     그룹5   기타  단일로   평지
# 1             횡단중   65세이상     그룹1     그룹2        그룹5     그룹4   시도  단일로   평지
# 2      길가장자리구역통행중   20세이하     그룹1     그룹2      기타/불명     그룹4   시도  단일로   평지
# 3      길가장자리구역통행중  21-30세     그룹1     그룹1      기타/불명     그룹1   기타  단일로   평지
# 4             횡단중  41-50세     그룹1     그룹2        그룹5     그룹4   기타  단일로   평지
# ...           ...     ...     ...     ...        ...     ...  ...  ...  ...
# 58054  길가장자리구역통행중  51-60세     그룹1     그룹2        그룹2     그룹4   시도  단일로   평지
# 58055       보도통행중  21-30세      기타     그룹1        그룹2     그룹4   군도  교차로   평지
# 58056       차도통행중  31-40세     그룹1     그룹2        그룹4     그룹4   군도  단일로   평지
# 58057          기타   65세이상     그룹1     그룹2        그룹4     그룹4   시도  단일로   평지
# 58058         횡단중  31-40세     그룹1     그룹3        그룹4     그룹4   기타  교차로   평지
#
#         발생시각  심각도
# 0          낮    0
# 1      출퇴근시간    1
# 2      출퇴근시간    0
# 3          낮    1
# 4          낮    1
# ...      ...  ...
# 58054      낮    0
# 58055  출퇴근시간    0
# 58056  출퇴근시간    1
# 58057  출퇴근시간    1
# 58058  출퇴근시간    1
#
# [58059 rows x 11 columns]

# %% [markdown]
# # 전체 변수들과의 ols 회귀분석 진행
# ### 설명변수(X)와 타겟변수(Y)를 분리/학습데이터와 평가데이터를 분할
# ##### Split Data Set Shape 출력물

# %%
feature_columns = corolla.columns.difference(["심각도"]) # Target column 빼기

y=pd.DataFrame(df['심각도'])
x=df.drop(['심각도'],axis=1)
x2=pd.get_dummies(x,drop_first=True)
X = x2


train_x, test_x, train_y, test_y = train_test_split(X,y, train_size = 0.7, test_size = 0.3)

print(train_x.shape, test_x.shape, train_y.shape, test_y.shape)
# Out:
# (40641, 44) (17418, 44) (40641, 1) (17418, 1)

# %% [markdown]
# # train & OLS 회귀모델 적합

# %%
full_model = sm.OLS(train_y,train_x)
fitted_full_model = full_model.fit()

fitted_full_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                    심각도   R-squared (uncentered):                   0.696
# Model:                            OLS   Adj. R-squared (uncentered):              0.696
# Method:                 Least Squares   F-statistic:                              2111.
# Date:                Wed, 25 Nov 2020   Prob (F-statistic):                        0.00
# Time:                        10:04:20   Log-Likelihood:                         -25251.
# No. Observations:               40641   AIC:                                  5.059e+04
# Df Residuals:                   40597   BIC:                                  5.097e+04
# Df Model:                          44
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# 사고유형_길가장자리구역통행중     -0.0177      0.010     -1.857      0.063      -0.036       0.001
# 사고유형_보도통행중           0.0321      0.012      2.599      0.009       0.008       0.056
# 사고유형_차도통행중           0.0231      0.008      2.770      0.006       0.007       0.039
# 사고유형_횡단중             0.0684      0.006     11.974      0.000       0.057       0.080
# 연령가해자_21-30세         0.0182      0.017      1.080      0.280      -0.015       0.051
# 연령가해자_31-40세         0.0091      0.017      0.550      0.582      -0.023       0.041
# 연령가해자_41-50세         0.0232      0.016      1.426      0.154      -0.009       0.055
# 연령가해자_51-60세         0.0085      0.016      0.525      0.599      -0.023       0.040
# 연령가해자_61-64세         0.0118      0.017      0.676      0.499      -0.022       0.046
# 연령가해자_65세이상          0.0080      0.017      0.481      0.630      -0.024       0.040
# 연령가해자_기타/불명         -0.2123      0.031     -6.801      0.000      -0.274      -0.151
# 법규위반가해자_그룹2          0.0174      0.006      2.871      0.004       0.006       0.029
# 법규위반가해자_그룹3          0.1947      0.029      6.748      0.000       0.138       0.251
# 법규위반가해자_기타          -0.0083      0.011     -0.722      0.470      -0.031       0.014
# 행동유형가해자_그룹2          0.0674      0.008      8.256      0.000       0.051       0.083
# 행동유형가해자_그룹3          0.0469      0.009      5.218      0.000       0.029       0.065
# 행동유형가해자_그룹4         -0.1029      0.020     -5.136      0.000      -0.142      -0.064
# 행동유형가해자_기타/불명        0.0038      0.018      0.207      0.836      -0.032       0.040
# 피해자신체상해주부위_그룹2       0.2726      0.040      6.882      0.000       0.195       0.350
# 피해자신체상해주부위_그룹3       0.3971      0.039     10.158      0.000       0.320       0.474
# 피해자신체상해주부위_그룹4       0.4867      0.039     12.469      0.000       0.410       0.563
# 피해자신체상해주부위_그룹5       0.5453      0.039     13.952      0.000       0.469       0.622
# 피해자신체상해주부위_그룹6       0.6185      0.040     15.531      0.000       0.540       0.697
# 피해자신체상해주부위_기타/불명     0.4280      0.039     10.966      0.000       0.351       0.504
# 차량용도가해자_그룹2         -0.0498      0.011     -4.663      0.000      -0.071      -0.029
# 차량용도가해자_그룹3         -0.0649      0.011     -6.000      0.000      -0.086      -0.044
# 차량용도가해자_그룹4         -0.0422      0.005     -7.770      0.000      -0.053      -0.032
# 차량용도가해자_그룹5         -0.1479      0.016     -9.429      0.000      -0.179      -0.117
# 차량용도가해자_기타/불명       -0.1068      0.031     -3.423      0.001      -0.168      -0.046
# 도로종류_군도              0.1732      0.042      4.098      0.000       0.090       0.256
# 도로종류_기타              0.0796      0.041      1.920      0.055      -0.002       0.161
# 도로종류_시도              0.1300      0.041      3.147      0.002       0.049       0.211
# 도로종류_일반국도            0.1948      0.042      4.609      0.000       0.112       0.278
# 도로종류_지방도             0.1587      0.042      3.783      0.000       0.076       0.241
# 도로종류_특별광역시도          0.1078      0.041      2.612      0.009       0.027       0.189
# 도로형태_기타/불명          -0.0053      0.012     -0.455      0.649      -0.028       0.018
# 도로형태_단일로            -0.0009      0.005     -0.158      0.875      -0.011       0.010
# 도로형태_주차장            -0.0350      0.028     -1.246      0.213      -0.090       0.020
# 도로선형_내리막             0.0511      0.018      2.811      0.005       0.015       0.087
# 도로선형_오르막             0.0205      0.018      1.111      0.267      -0.016       0.057
# 도로선형_평지             -0.0055      0.016     -0.346      0.729      -0.037       0.026
# 발생시각_새벽~아침           0.1070      0.008     14.178      0.000       0.092       0.122
# 발생시각_저녁~자정           0.0529      0.008      6.775      0.000       0.038       0.068
# 발생시각_출퇴근시간           0.0291      0.005      5.699      0.000       0.019       0.039
# ==============================================================================
# Omnibus:                    49251.938   Durbin-Watson:                   1.999
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5223.666
# Skew:                          -0.628   Prob(JB):                         0.00
# Kurtosis:                       1.773   Cond. No.                         104.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# # 다중공선성 검사
#
# ## 출력된 VIF Factor 값이 10크면 다중공선성이 있다는 것이다.
# ### const 값은 무시

# %%
import statsmodels.api as sm

corolla = pd.concat([x2,y],axis=1)
corolla = sm.add_constant(corolla, has_constant='add')

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(corolla.values, i) for i in range(corolla.shape[1])]
vif["features"] = corolla.columns
vif
# Out:
#      VIF Factor          features
# 0   1443.871057             const
# 1      1.175207   사고유형_길가장자리구역통행중
# 2      1.187606        사고유형_보도통행중
# 3      1.238876        사고유형_차도통행중
# 4      1.633875          사고유형_횡단중
# 5      4.811707      연령가해자_21-30세
# 6      7.143129      연령가해자_31-40세
# 7      9.278885      연령가해자_41-50세
# 8     10.519130      연령가해자_51-60세
# 9      4.761032      연령가해자_61-64세
# 10     6.758651       연령가해자_65세이상
# 11     5.328628       연령가해자_기타/불명
# 12     1.240045       법규위반가해자_그룹2
# 13     1.019994       법규위반가해자_그룹3
# 14     1.237780        법규위반가해자_기타
# 15     3.322718       행동유형가해자_그룹2
# 16     3.343436       행동유형가해자_그룹3
# 17     1.245249       행동유형가해자_그룹4
# 18     2.677859     행동유형가해자_기타/불명
# 19    33.635279    피해자신체상해주부위_그룹2
# 20    71.767800    피해자신체상해주부위_그룹3
# 21    85.202438    피해자신체상해주부위_그룹4
# 22    72.280846    피해자신체상해주부위_그룹5
# 23    26.393826    피해자신체상해주부위_그룹6
# 24    80.572186  피해자신체상해주부위_기타/불명
# 25     1.349647       차량용도가해자_그룹2
# 26     1.365526       차량용도가해자_그룹3
# 27     1.459434       차량용도가해자_그룹4
# 28     1.317476       차량용도가해자_그룹5
# 29     4.687500     차량용도가해자_기타/불명
# 30    42.986637           도로종류_군도
# 31    78.690899           도로종류_기타
# 32   193.641712           도로종류_시도
# 33    43.377670         도로종류_일반국도
# 34    57.173949          도로종류_지방도
# 35   215.209815       도로종류_특별광역시도
# 36     1.349321        도로형태_기타/불명
# 37     1.445403          도로형태_단일로
# 38     1.066062          도로형태_주차장
# 39     3.798263          도로선형_내리막
# 40     3.649037          도로선형_오르막
# 41     6.229629           도로선형_평지
# 42     1.194993        발생시각_새벽~아침
# 43     1.183898        발생시각_저녁~자정
# 44     1.250832        발생시각_출퇴근시간
# 45     1.094433               심각도

# %% [markdown]
# ## VIF Factor가 10 이상인 아래 컬럼 삭제 후 재진행

# %% [markdown]
# #### '연령가해자_51-60세', '피해자신체상해주부위_그룹2', '피해자신체상해주부위_그룹3',
# #### '피해자신체상해주부위_그룹4', '피해자신체상해주부위_그룹5',
# #### '피해자신체상해주부위_그룹6', '피해자신체상해주부위_기타/불명',
# #### '도로종류_군도' ,'도로종류_기타', '도로종류_시도', '도로종류_일반국도',
# #### '도로종류_지방도', '도로종류_특별광역시도'

# %%
x2=x2.drop(['연령가해자_51-60세', '피해자신체상해주부위_그룹2', '피해자신체상해주부위_그룹3', '피해자신체상해주부위_그룹4', '피해자신체상해주부위_그룹5', '피해자신체상해주부위_그룹6', '피해자신체상해주부위_기타/불명', '도로종류_군도' ,'도로종류_기타', '도로종류_시도', '도로종류_일반국도','도로종류_지방도', '도로종류_특별광역시도'],axis=1)

# %% [markdown]
# ### 삭제 한 후의 ols 결과

# %%
ols = OLS(y,x2).fit().summary()
ols
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                    심각도   R-squared (uncentered):                   0.680
# Model:                            OLS   Adj. R-squared (uncentered):              0.679
# Method:                 Least Squares   F-statistic:                              3969.
# Date:                Wed, 25 Nov 2020   Prob (F-statistic):                        0.00
# Time:                        10:06:29   Log-Likelihood:                         -37707.
# No. Observations:               58059   AIC:                                  7.548e+04
# Df Residuals:                   58028   BIC:                                  7.575e+04
# Df Model:                          31
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# 사고유형_길가장자리구역통행중     0.0063      0.008      0.770      0.441      -0.010       0.022
# 사고유형_보도통행중          0.0621      0.011      5.842      0.000       0.041       0.083
# 사고유형_차도통행중          0.0573      0.007      8.053      0.000       0.043       0.071
# 사고유형_횡단중            0.1088      0.005     22.502      0.000       0.099       0.118
# 연령가해자_21-30세        0.0306      0.007      4.131      0.000       0.016       0.045
# 연령가해자_31-40세        0.0259      0.006      4.205      0.000       0.014       0.038
# 연령가해자_41-50세        0.0397      0.005      7.316      0.000       0.029       0.050
# 연령가해자_61-64세        0.0263      0.008      3.492      0.000       0.012       0.041
# 연령가해자_65세이상         0.0342      0.006      5.458      0.000       0.022       0.046
# 연령가해자_기타/불명        -0.2437      0.025     -9.936      0.000      -0.292      -0.196
# 법규위반가해자_그룹2         0.0200      0.005      3.837      0.000       0.010       0.030
# 법규위반가해자_그룹3         0.2351      0.025      9.536      0.000       0.187       0.283
# 법규위반가해자_기타          0.0240      0.010      2.437      0.015       0.005       0.043
# 행동유형가해자_그룹2         0.1341      0.007     19.787      0.000       0.121       0.147
# 행동유형가해자_그룹3         0.1267      0.007     17.248      0.000       0.112       0.141
# 행동유형가해자_그룹4        -0.0416      0.017     -2.466      0.014      -0.075      -0.009
# 행동유형가해자_기타/불명       0.0673      0.016      4.284      0.000       0.037       0.098
# 차량용도가해자_그룹2        -0.0261      0.009     -2.884      0.004      -0.044      -0.008
# 차량용도가해자_그룹3        -0.0558      0.009     -6.266      0.000      -0.073      -0.038
# 차량용도가해자_그룹4        -0.0159      0.005     -3.454      0.001      -0.025      -0.007
# 차량용도가해자_그룹5        -0.1368      0.013    -10.795      0.000      -0.162      -0.112
# 차량용도가해자_기타/불명      -0.0749      0.027     -2.742      0.006      -0.128      -0.021
# 도로형태_기타/불명          0.1258      0.009     13.720      0.000       0.108       0.144
# 도로형태_단일로            0.0303      0.005      6.694      0.000       0.021       0.039
# 도로형태_주차장            0.0948      0.023      4.061      0.000       0.049       0.141
# 도로선형_내리막            0.4795      0.011     43.922      0.000       0.458       0.501
# 도로선형_오르막            0.4450      0.011     39.734      0.000       0.423       0.467
# 도로선형_평지             0.4220      0.008     54.435      0.000       0.407       0.437
# 발생시각_새벽~아침          0.1333      0.006     20.582      0.000       0.121       0.146
# 발생시각_저녁~자정          0.0618      0.007      9.283      0.000       0.049       0.075
# 발생시각_출퇴근시간          0.0535      0.004     12.267      0.000       0.045       0.062
# ==============================================================================
# Omnibus:                    59458.980   Durbin-Watson:                   1.978
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7547.034
# Skew:                          -0.644   Prob(JB):                         0.00
# Kurtosis:                       1.791   Cond. No.                         28.4
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ## 여기서 P값이 유의하지 않은 <사고유형_길가장자리구역통행중> 제거하고 다시 ols

# %%
x2=x2.drop(['사고유형_길가장자리구역통행중'],axis=1)
ols = OLS(y,x2).fit().summary()
ols
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                    심각도   R-squared (uncentered):                   0.680
# Model:                            OLS   Adj. R-squared (uncentered):              0.679
# Method:                 Least Squares   F-statistic:                              4101.
# Date:                Wed, 25 Nov 2020   Prob (F-statistic):                        0.00
# Time:                        10:07:25   Log-Likelihood:                         -37708.
# No. Observations:               58059   AIC:                                  7.548e+04
# Df Residuals:                   58029   BIC:                                  7.574e+04
# Df Model:                          30
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# 사고유형_보도통행중        0.0611      0.011      5.791      0.000       0.040       0.082
# 사고유형_차도통행중        0.0561      0.007      8.086      0.000       0.042       0.070
# 사고유형_횡단중          0.1076      0.005     23.451      0.000       0.099       0.117
# 연령가해자_21-30세      0.0307      0.007      4.140      0.000       0.016       0.045
# 연령가해자_31-40세      0.0259      0.006      4.207      0.000       0.014       0.038
# 연령가해자_41-50세      0.0397      0.005      7.323      0.000       0.029       0.050
# 연령가해자_61-64세      0.0263      0.008      3.498      0.000       0.012       0.041
# 연령가해자_65세이상       0.0343      0.006      5.473      0.000       0.022       0.047
# 연령가해자_기타/불명      -0.2435      0.025     -9.927      0.000      -0.292      -0.195
# 법규위반가해자_그룹2       0.0198      0.005      3.813      0.000       0.010       0.030
# 법규위반가해자_그룹3       0.2350      0.025      9.531      0.000       0.187       0.283
# 법규위반가해자_기타        0.0237      0.010      2.408      0.016       0.004       0.043
# 행동유형가해자_그룹2       0.1344      0.007     19.846      0.000       0.121       0.148
# 행동유형가해자_그룹3       0.1269      0.007     17.299      0.000       0.113       0.141
# 행동유형가해자_그룹4      -0.0416      0.017     -2.467      0.014      -0.075      -0.009
# 행동유형가해자_기타/불명     0.0673      0.016      4.281      0.000       0.036       0.098
# 차량용도가해자_그룹2      -0.0266      0.009     -2.946      0.003      -0.044      -0.009
# 차량용도가해자_그룹3      -0.0558      0.009     -6.265      0.000      -0.073      -0.038
# 차량용도가해자_그룹4      -0.0158      0.005     -3.437      0.001      -0.025      -0.007
# 차량용도가해자_그룹5      -0.1370      0.013    -10.808      0.000      -0.162      -0.112
# 차량용도가해자_기타/불명    -0.0747      0.027     -2.734      0.006      -0.128      -0.021
# 도로형태_기타/불명        0.1259      0.009     13.721      0.000       0.108       0.144
# 도로형태_단일로          0.0304      0.005      6.743      0.000       0.022       0.039
# 도로형태_주차장          0.0947      0.023      4.056      0.000       0.049       0.140
# 도로선형_내리막          0.4804      0.011     44.250      0.000       0.459       0.502
# 도로선형_오르막          0.4460      0.011     40.057      0.000       0.424       0.468
# 도로선형_평지           0.4228      0.008     55.091      0.000       0.408       0.438
# 발생시각_새벽~아침        0.1333      0.006     20.577      0.000       0.121       0.146
# 발생시각_저녁~자정        0.0618      0.007      9.277      0.000       0.049       0.075
# 발생시각_출퇴근시간        0.0536      0.004     12.274      0.000       0.045       0.062
# ==============================================================================
# Omnibus:                    59353.560   Durbin-Watson:                   1.978
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7544.586
# Skew:                          -0.644   Prob(JB):                         0.00
# Kurtosis:                       1.791   Cond. No.                         28.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-81-6a85a982cba3> in <module>
# ----> 1 y_pred = ols.predict(test_x)
#
# AttributeError: 'Summary' object has no attribute 'predict'

# %% [markdown]
# ###  다중공선성 재검사

# %%
import statsmodels.api as sm

corolla = pd.concat([x2,y],axis=1)
corolla = sm.add_constant(corolla, has_constant='add')

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(corolla.values, i) for i in range(corolla.shape[1])]
vif["features"] = corolla.columns
vif
# Out:
#     VIF Factor       features
# 0    69.565015          const
# 1     1.166212     사고유형_보도통행중
# 2     1.168746     사고유형_차도통행중
# 3     1.445122       사고유형_횡단중
# 4     1.231805   연령가해자_21-30세
# 5     1.326784   연령가해자_31-40세
# 6     1.386348   연령가해자_41-50세
# 7     1.188031   연령가해자_61-64세
# 8     1.293446    연령가해자_65세이상
# 9     4.299632    연령가해자_기타/불명
# 10    1.231798    법규위반가해자_그룹2
# 11    1.014651    법규위반가해자_그룹3
# 12    1.231515     법규위반가해자_기타
# 13    3.275589    행동유형가해자_그룹2
# 14    3.319022    행동유형가해자_그룹3
# 15    1.243272    행동유형가해자_그룹4
# 16    2.670129  행동유형가해자_기타/불명
# 17    1.334973    차량용도가해자_그룹2
# 18    1.258061    차량용도가해자_그룹3
# 19    1.448108    차량용도가해자_그룹4
# 20    1.155260    차량용도가해자_그룹5
# 21    4.677978  차량용도가해자_기타/불명
# 22    1.320502     도로형태_기타/불명
# 23    1.435521       도로형태_단일로
# 24    1.054406       도로형태_주차장
# 25    3.761938       도로선형_내리막
# 26    3.608359       도로선형_오르막
# 27    6.146673        도로선형_평지
# 28    1.190946     발생시각_새벽~아침
# 29    1.179154     발생시각_저녁~자정
# 30    1.248101     발생시각_출퇴근시간
# 31    1.054838            심각도

# %% [markdown]
# ### 모든 속성들의 VIF Factor값이 10을 넘지 않는다.

# %% [markdown]
# ---

# %% [markdown]
# ---
